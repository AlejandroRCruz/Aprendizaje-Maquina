# %% [markdown]
# # Visualizando dato y extrayendo metricas

# %%
import pandas as pd
Financiamientos=pd.read_csv("Financiamientos_2026.csv") #hubo que cambiar año por anio
Financiamientos.head(5) # Imprimimos las primeras 5 filas del csv
# Out:
#    anio  mes  cve_ent         entidad  cve_mun       municipio  organismo  \
# 0  2026    1        1  Aguascalientes      NaN  No distribuido          4
# 1  2026    1        1  Aguascalientes      1.0  Aguascalientes          2
# 2  2026    1        1  Aguascalientes      1.0  Aguascalientes          2
# 3  2026    1        1  Aguascalientes      1.0  Aguascalientes          2
# 4  2026    1        1  Aguascalientes      1.0  Aguascalientes          2
#
#    modalidad  destino  tipo  sexo  edad_rango  ingresos_rango  vivienda_valor  \
# 0          3        1     1   NaN         NaN             NaN             NaN
# 1          1        2     2   1.0         1.0             3.0             4.0
# 2          1        2     2   1.0         2.0             4.0             4.0
# 3          1        2     2   2.0         2.0             1.0             4.0
# 4          1        2     2   2.0         2.0             4.0             5.0
#
#    acciones      monto
# 0       0.0   122400.0
# ...

# %%
# Obtenemos tamaños y tipos de dato
print(f"Tenemos {len(Financiamientos)} ejemplos")
print(f'Tenemos {len(Financiamientos.columns)} caracteristicas')
print("\n")
print(Financiamientos.info())
# Out:
# Tenemos 41971 ejemplos
# Tenemos 16 caracteristicas
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41971 entries, 0 to 41970
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   anio            41971 non-null  int64
#  1   mes             41971 non-null  int64
#  2   cve_ent         41971 non-null  int64
#  3   entidad         41971 non-null  object
#  4   cve_mun         41945 non-null  float64
#  5   municipio       41971 non-null  object
#  6   organismo       41971 non-null  int64
#  7   modalidad       41971 non-null  int64
#  8   destino         41971 non-null  int64
#  9   tipo            41971 non-null  int64
#  10  sexo            41945 non-null  float64
#  11  edad_rango      40988 non-null  float64
#  12  ingresos_rango  41631 non-null  float64
#  13  vivienda_valor  31555 non-null  float64
#  14  acciones        41971 non-null  float64
#  15  monto           41971 non-null  float64
# ...

# %%
#Obtenemos estadisticas basicas de cada columna
Financiamientos.describe()
# Out:
#           anio           mes       cve_ent       cve_mun     organismo  \
# count  41971.0  41971.000000  41971.000000  41945.000000  41971.000000
# mean    2026.0      1.496676     16.582045     41.755108      1.437326
# std        0.0      0.499995      8.295177     49.069213      1.261817
# min     2026.0      1.000000      1.000000      1.000000      1.000000
# 25%     2026.0      1.000000     11.000000     11.000000      1.000000
# 50%     2026.0      1.000000     15.000000     28.000000      1.000000
# 75%     2026.0      2.000000     23.000000     53.000000      2.000000
# max     2026.0      2.000000     32.000000    570.000000     26.000000
#
#           modalidad       destino          tipo          sexo    edad_rango  \
# count  41971.000000  41971.000000  41971.000000  41945.000000  40988.000000
# mean       2.025875      2.369017      1.395440      1.423817      1.804528
# std        0.944037      1.420590      0.488951      0.494168      0.505849
# ...

# %% [markdown]
# ## Leamos el diccionario de financiamiento para entender las variables

# %%
diccionario=pd.read_excel("diccionario_financiamiento.xlsx")
# mostramos los primeros valores
for i in range(len(diccionario)):
    if not(pd.isna(diccionario["Nemónico del campo"][i])):
        print(f'El campo {diccionario["Nemónico del campo"][i]} es: {diccionario["Alias"][i]}\nCon descripción: {diccionario["Descripción"][i]}\n')
# Out:
# El campo año es: Año
# Con descripción: Año
#
# El campo mes es: Mes
# Con descripción: Mes
#
# El campo cve_ent es: Clave de entidad federativa
# Con descripción: Clave de la entidad federativa, de acuerdo con el catálogo de entidades federativas, municipios y localidades del Instituto Nacional de Estadística y Geografía (INEGI),  en la que se ejerció el financiamiento
#
# El campo entidad es: Nombre de la entidad federativa
# Con descripción: Nombre de la entidad federativa, de acuerdo con el catálogo de entidades federativas, municipios y localidades del INEGI, en la que se ejerció el financiamiento
#
# El campo cve_mun es: Clave municipal
# Con descripción: Clave del  municipio, de acuerdo con el catálogo de entidades federativas, municipios y localidades del Instituto Nacional de Estadística y Geografía (INEGI),  en la que se ejerció el financiamiento
#
# El campo municipio es: Nombre del municipio
# ...
